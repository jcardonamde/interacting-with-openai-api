# %% [markdown]
# <a href="https://colab.research.google.com/github/jcardonamde/interacting-with-openai-api/blob/main/02_chat_completion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# Importar librería

# %%
from openai import OpenAI

# %% [markdown]
# Cargar API Key de OpenAI para conectar modelos

# %%
openai = OpenAI(api_key='write_your_APIKey_from_OpenAI')

# %% [markdown]
# Estructura base para su uso:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Uso de chat completion

# %%
response = openai.chat.completions.create(
    model = 'gpt-3.5-turbo',
    messages = [
        {"role": "system", "content": "Eres un asistente que da informacion sobre deportes"},
        {"role": "user", "content": "Quién gano el mundial de fútbol?"},
        {"role": "assistant", "content": "El mundial de 2022 lo gano Argentina"},
        {"role": "user", "content": "Dónde se jugó?"},
    ]
)
print(response.choices[0].message.content)
# Out:
# El Mundial de 2022 se jugó en Qatar.

# %%
response2 = openai.chat.completions.create(
    model = 'gpt-3.5-turbo',
    messages = [
        {"role": "system", "content": "Eres un asistente que da informacion sobre deportes"},
        {"role": "user", "content": "Quién gano el mundial de fútbol?"},
        {"role": "assistant", "content": "El mundial de 2022 lo gano Argentina"},
        {"role": "user", "content": "Dónde se jugó?"},
    ],
    temperature = 0.2
)
print(response2.choices[0].message.content)
# Out:
# El Mundial de Fútbol de 2022 se jugó en Qatar.

# %%
response3 = openai.chat.completions.create(
    model = 'gpt-3.5-turbo',
    messages = [
        {"role": "system", "content": "Eres un asistente que da informacion sobre deportes"},
        {"role": "user", "content": "Quién gano el mundial de fútbol?"},
        {"role": "assistant", "content": "El mundial de 2022 lo gano Argentina"},
        {"role": "user", "content": "Dónde se jugó?"},
    ],
    temperature = 1
)
print(response3.choices[0].message.content)
# Out:
# El mundial de fútbol de 2022 se jugó en Qatar. Fue la primera vez que este país del Medio Oriente fue sede de un Mundial de la FIFA.
